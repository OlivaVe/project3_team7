# %%
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv('./divorces_2000-2015_final_db_2.csv')
data1
# Out:
#      Divorce_date Type_of_divorce Nationality_partner_man DOB_partner_man  \
# 0        9/6/2006       Necesario                MEXICANA        18/12/75
# 1        1/2/2006       Necesario                MEXICANA        30/10/75
# 2        1/2/2007       Necesario                MEXICANA        13/12/70
# 3        1/2/2007       Necesario                MEXICANA        17/02/75
# 4        1/2/2008      Voluntario                MEXICANA       2/12/1976
# ...           ...             ...                     ...             ...
# 3503     31/10/12       Necesario                MEXICANA        16/09/61
# 3504     31/10/12      Voluntario                MEXICANA        29/10/77
# 3505     31/10/13      Voluntario                MEXICANA      10/11/1982
# 3506     31/10/13      Voluntario                MEXICANA        28/10/54
# 3507     31/12/13      Voluntario                MEXICANA        22/06/60
#
#      DOB_pm_ddmm Zodiac_sign_man Place_of_birth_partner_man  \
# 0         18-Dec     Sagittarius          XALAPA - ENRIQUEZ
# 1         30-Oct         Scorpio          XALAPA - ENRIQUEZ
# 2         13-Dec     Sagittarius          XALAPA - ENRIQUEZ
# 3         17-Feb        Aquarius           DISTRITO FEDERAL
# 4          2-Dec     Sagittarius               CIUDAD MANTE
# ...          ...             ...                        ...
# 3503      16-Sep           Virgo          XALAPA - ENRIQUEZ
# 3504      29-Oct         Scorpio                    MORELIA
# 3505      10-Nov         Scorpio                   VERACRUZ
# 3506      28-Oct         Scorpio          XALAPA - ENRIQUEZ
# 3507      22-Jun          Cancer                TLACOTALPAN
#
#      Birth_municipality_of_partner_man Birth_federal_partner_man  \
# 0                               XALAPA                  VERACRUZ
# 1                               XALAPA                  VERACRUZ
# 2                               XALAPA                  VERACRUZ
# 3                     DISTRITO FEDERAL          DISTRITO FEDERAL
# 4                         CIUDAD MANTE                TAMAULIPAS
# ...                                ...                       ...
# 3503                            XALAPA                  VERACRUZ
# 3504                           MORELIA                 MICHOACAN
# 3505                          VERACRUZ                  VERACRUZ
# 3506                            XALAPA                  VERACRUZ
# 3507                       TLACOTALPAN                  VERACRUZ
#
#      Birth_country_partner_man  ...  Marriage_certificate_municipality  \
# 0                       MEXICO  ...                             XALAPA
# 1                       MEXICO  ...                             XALAPA
# 2                       MEXICO  ...                             XALAPA
# 3                       MEXICO  ...                             XALAPA
# 4                       MEXICO  ...                             XALAPA
# ...                        ...  ...                                ...
# 3503                    MEXICO  ...                             XALAPA
# 3504                    MEXICO  ...                             XALAPA
# 3505                    MEXICO  ...                             XALAPA
# 3506                    MEXICO  ...                             XALAPA
# 3507                    MEXICO  ...                           COATEPEC
#
#      Marriage_certificate_federal Level_of_education_partner_man  \
# 0                        VERACRUZ                     SECUNDARIA
# 1                        VERACRUZ                    PROFESIONAL
# 2                        VERACRUZ                    PROFESIONAL
# 3                        VERACRUZ                    PROFESIONAL
# 4                        VERACRUZ                    PROFESIONAL
# ...                           ...                            ...
# 3503                     VERACRUZ                    PROFESIONAL
# 3504                     VERACRUZ                    PROFESIONAL
# 3505                     VERACRUZ                    PROFESIONAL
# 3506                     VERACRUZ                    PROFESIONAL
# 3507                     VERACRUZ                    PROFESIONAL
#
#      Employment_status_partner_man  Level_of_education_partner_woman  \
# 0                           OBRERO                        SECUNDARIA
# 1                         EMPLEADO                      PREPARATORIA
# 2                         EMPLEADO                       PROFESIONAL
# 3                         EMPLEADO                       PROFESIONAL
# 4                         EMPLEADO                       PROFESIONAL
# ...                            ...                               ...
# 3503                      EMPLEADO                        SECUNDARIA
# 3504                      EMPLEADO                       PROFESIONAL
# 3505                      EMPLEADO                       PROFESIONAL
# 3506                      EMPLEADO                       PROFESIONAL
# 3507                      EMPLEADO                       PROFESIONAL
#
#      Employment_status_partner_woman Marriage_duration  \
# 0                           EMPLEADO                 5
# 1                         NO TRABAJA                 7
# 2                         NO TRABAJA                15
# 3                           EMPLEADO                 6
# 4                         NO TRABAJA                 1
# ...                              ...               ...
# 3503                      NO TRABAJA                25
# 3504                        EMPLEADO                 3
# 3505                        EMPLEADO                 1
# 3506                        EMPLEADO                35
# 3507                        EMPLEADO                 4
#
#      Marriage_duration_months Num_Children Custody
# 0                         NaN          1.0     NaN
# 1                         NaN          2.0   MADRE
# 2                         NaN          2.0   MADRE
# 3                         NaN          1.0   MADRE
# 4                         7.0          NaN     NaN
# ...                       ...          ...     ...
# 3503                      NaN          3.0   MADRE
# 3504                     11.0          NaN     NaN
# 3505                      NaN          NaN     NaN
# 3506                      NaN          2.0     NaN
# 3507                      NaN          NaN     NaN
#
# [3508 rows x 46 columns]

# %%
#COUNT Zodiac Sign for the MEN
plt.figure(figsize=(12, 4))
plot = sns.countplot(x="Zodiac_sign_man", data=data1, palette="colorblind")
plt.title('Men Zodiac Signs')
plt.xlabel("")
plt.ylabel("count of zodiacs")
plt.show()

# %%
#COUNT Zodiac Sign for the WOMAN

plt.figure(figsize=(12, 4))
plot = sns.countplot(x="Zodiac_sign_woman", data=data1, palette="deep")
plt.title('Woman Zodiac Signs')
plt.xlabel("")
plt.ylabel("count of zodiacs")
plt.show()

# %%
#count each of the possible combinations of pairs by using the matrix 

div_data = pd.DataFrame(data1) 
adjacency_matrix = pd.crosstab(div_data['Zodiac_sign_man'], div_data['Zodiac_sign_woman'])

adjacency_matrix = adjacency_matrix.loc[adjacency_matrix.sum(axis=1).sort_values(ascending=False).index]
adjacency_matrix = adjacency_matrix[adjacency_matrix.sum(axis=0).sort_values(ascending=False).index]


idx = adjacency_matrix.columns.union(adjacency_matrix.index)
adjacency_matrix = adjacency_matrix.reindex(index=idx, columns=idx, fill_value=0)
print(adjacency_matrix.head(12))
# Out:
#              Aquarius  Aries  Cancer  Capricorn  Gemini  Leo  Libra  Pisces  \
# Aquarius           20     24      17         20      27   26     18      27
# Aries              18     21      28         27      20   28     24      15
# Cancer             36     29      32         14      24   31     21      31
# Capricorn          32     21      19         17      32   29     10      21
# Gemini             22     20      18         20      22   31     28      31
# Leo                29     23      26         24      26   19     30      27
# Libra              21     14      32         18      17   16     31      19
# Pisces             30     26      14         25      28   27     28      29
# Sagittarius        22     27      17         30      16   16     29      23
# Scorpio            27     25      23         24      25   23     29      34
# Taurus             18     27      27         22      21   18     21      26
# Virgo              13     24      28         14      26   24     25      32
#
#              Sagittarius  Scorpio  Taurus  Virgo
# Aquarius              21       25      22     28
# Aries                 21       22      20     21
# Cancer                25       29      22     24
# Capricorn             24       22      17     18
# Gemini                23       26      29     23
# Leo                   17       25      29     30
# Libra                 27       22      24     17
# Pisces                26       34      25     31
# Sagittarius           29       22      29     36
# Scorpio               24       28      33     29
# Taurus                34       19      25     29
# Virgo                 27       31      24     34

# %%
div_data['Zodiac_combinations'] = div_data['Zodiac_sign_man'] + div_data['Zodiac_sign_woman']


combination_counts = div_data['Zodiac_combinations'].value_counts().sort_values(ascending=False)


plt.figure(figsize=(30, 10))
plot = sns.countplot(x="Zodiac_combinations", data=div_data, palette="viridis")
plt.title('Zodiac Signs Combinations')
plt.xlabel("")
plt.ylabel("count of combinations")
plt.xticks(rotation=90)

plt.show()
