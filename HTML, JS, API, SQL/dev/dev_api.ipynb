# %%
# Dependencies
import pandas as pd
import seaborn as sns

from sqlalchemy import create_engine

# %%
# Create database connection
connection_string= 'postgresql+psycopg2://postgres:jesfer2011@localhost:5432/challenge3'
engine = create_engine(connection_string)

# %%
response = pd.read_sql('select * from divorces', engine)
### One option would be to send to JS a list of dicts
response = response.to_dict(orient='records')
response
# Out:
# [{'divorce_date': '9/6/2006',
#   'type_of_divorce': 'Necesario',
#   'nationality_partner_man': 'MEXICANA',
#   'dob_partner_man': '18/12/75',
#   'dob_pm_ddmm': '18-Dec',
#   'zodiac_sign_man': 'Sagittarius',
#   'place_of_birth_partner_man': 'XALAPA - ENRIQUEZ',
#   'birth_municipality_of_partner_man': 'XALAPA',
#   'birth_federal_partner_man': 'VERACRUZ',
#   'birth_country_partner_man': 'MEXICO',
#   'age_partner_man': 30.0,
#   'residence_municipality_partner_man': 'XALAPA',
#   'residence_federal_partner_man': 'VERACRUZ',
#   'residence_country_partner_man': 'MEXICO',
#   'monthly_income_partner_man_peso': 2000.0,
#   'occupation_partner_man': 'PINTOR',
#   'place_of_residence_partner_man': 'XALAPA-ENRIQUEZ',
#   'nationality_partner_woman': 'MEXICANA',
#   'dob_partner_woman': '8/1/1983',
#   'dob_pw_ddmm': '8-Jan',
#   'zodiac_sign_woman': 'Capricorn',
#   'dob_registration_date_partner_woman': None,
#   'place_of_birth_partner_woman': 'PUEBLA',
# ...

# %%
response = pd.read_sql('select zodiac_sign_man, avg(monthly_income_partner_man_peso) from divorces group by zodiac_sign_man', engine)
response = {
    'labels': response['zodiac_sign_man'].to_list(),
    'values': response['avg'].to_list(),
}
response
# Out:
# {'labels': [None,
#   'Gemini',
#   'Sagittarius',
#   'Capricorn',
#   'Libra',
#   'Virgo',
#   'Aries',
#   'Cancer',
#   'Aquarius',
#   'Taurus',
#   'Leo',
#   'Pisces',
#   'Scorpio'],
#  'values': [nan,
#   7343.436734693878,
#   10698.032653061224,
#   10626.154285714285,
#   11582.868181818181,
#   8035.177865612648,
#   21950.1,
#   8306.026119402984,
#   7944.8430493273545,
#   10033.844017094018,
#   8254.322957198443,
#   13131.483636363637,
#   11351.884476534296]}

# %%
response = pd.read_sql('select zodiac_sign_woman, avg(monthly_income_partner_woman_peso) from divorces group by zodiac_sign_woman', engine)
response = {
        'labels1': response['zodiac_sign_woman'].to_list(),
        'values1': response['avg'].to_list(),
    }
response
# Out:
# {'labels1': [None,
#   'Gemini',
#   'Sagittarius',
#   'Capricorn',
#   'Libra',
#   'Virgo',
#   'Aries',
#   'Cancer',
#   'Aquarius',
#   'Taurus',
#   'Leo',
#   'Pisces',
#   'Scorpio'],
#  'values1': [nan,
#   6773.145,
#   7348.046341463415,
#   12094.17543859649,
#   6387.930412371134,
#   6854.354838709677,
#   7179.331707317073,
#   6919.243243243243,
#   7791.794871794872,
#   6615.669166666667,
#   7458.5901639344265,
#   6571.846511627907,
#   7588.923444976077]}

# %%
response = pd.read_sql('select zodiac_sign_woman, count(monthly_income_partner_woman_peso) from divorces group by zodiac_sign_woman', engine)
response = {
        'labels1': response['zodiac_sign_woman'].to_list(),
        'values1': response['count'].to_list(),
    }
response
# Out:
# {'labels1': [None,
#   'Gemini',
#   'Sagittarius',
#   'Capricorn',
#   'Libra',
#   'Virgo',
#   'Aries',
#   'Cancer',
#   'Aquarius',
#   'Taurus',
#   'Leo',
#   'Pisces',
#   'Scorpio'],
#  'values1': [0, 200, 205, 171, 194, 217, 205, 185, 195, 192, 183, 215, 209]}
